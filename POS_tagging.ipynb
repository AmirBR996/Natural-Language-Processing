# %%
paragraph = """Quantum computing is an emerging technology that harnesses quantum mechanics—specifically superposition and entanglement—to process information in fundamentally new ways. Unlike classical computers that use binary bits (0 or 1), quantum machines utilize quantum bits, or qubits, which can exist in multiple states simultaneously, allowing them to tackle complex optimization, simulation, and cryptographic tasks exponentially faster than traditional supercomputers. While still in experimental stages, these systems promise breakthroughs in fields like medicine, AI, and material science by solving problems deemed impossible for conventional technology."""

# %%
import nltk
sentences = nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['quantum computing emerging technology harnesses quantum mechanics — specifically superposition entanglement — process information fundamentally new ways .',
#  'unlike classical computers use binary bits ( 0 1 ) , quantum machines utilize quantum bits , qubits , exist multiple states simultaneously , allowing tackle complex optimization , simulation , cryptographic tasks exponentially faster traditional supercomputers .',
#  'still experimental stages , systems promise breakthroughs fields like medicine , ai , material science solving problems deemed impossible conventional technology .']

# %%
import nltk

nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/amir/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])

    words = [
        word.lower()
        for word in words
        if word.lower() not in set(stopwords.words("english"))
    ]

    pos_tags = nltk.pos_tag(words)

    print(pos_tags)
# Out:
# [('quantum', 'NN'), ('computing', 'VBG'), ('emerging', 'VBG'), ('technology', 'NN'), ('harnesses', 'NNS'), ('quantum', 'VBP'), ('mechanics', 'NNS'), ('—', 'VBP'), ('specifically', 'RB'), ('superposition', 'JJ'), ('entanglement', 'NN'), ('—', 'NNP'), ('process', 'NN'), ('information', 'NN'), ('fundamentally', 'RB'), ('new', 'JJ'), ('ways', 'NNS'), ('.', '.')]
# ...

# %%
# Penn Treebank Tagset (Most Widely Used)

## Nouns

| Tag | Meaning | Example |
|-----|---------|---------|
| NN | Noun, singular or mass | dog, water |
| NNS | Noun, plural | dogs, cats |
| NNP | Proper noun, singular | London, John |
| NNPS | Proper noun, plural | Vikings, Alps |

## Pronouns

| Tag | Meaning | Example |
|-----|---------|---------|
| PRP | Personal pronoun | I, he, she, they |
| PRP$ | Possessive pronoun | my, his, their |
| WP | Wh-pronoun | who, what |
| WP$ | Possessive wh-pronoun | whose |

## Verbs

| Tag | Meaning | Example |
|-----|---------|---------|
| VB | Verb, base form | run, eat |
| VBD | Verb, past tense | ran, ate |
| VBG | Verb, gerund/present participle | running, eating |
| VBN | Verb, past participle | run, eaten |
| VBP | Verb, non-3rd person singular present | run, eat |
| VBZ | Verb, 3rd person singular present | runs, eats |
| MD | Modal | can, will, should |

## Adjectives

| Tag | Meaning | Example |
|-----|---------|---------|
| JJ | Adjective | big, happy |
| JJR | Adjective, comparative | bigger, happier |
| JJS | Adjective, superlative | biggest, happiest |

## Adverbs

| Tag | Meaning | Example |
|-----|---------|---------|
| RB | Adverb | quickly, very |
| RBR | Adverb, comparative | faster, more |
| RBS | Adverb, superlative | fastest, most |
| WRB | Wh-adverb | where, when, how |

## Determiners & Articles

| Tag | Meaning | Example |
|-----|---------|---------|
| DT | Determiner | the, a, an, this |
| PDT | Predeterminer | all, both, half |
| WDT | Wh-determiner | which, that |

## Conjunctions

| Tag | Meaning | Example |
|-----|---------|---------|
| CC | Coordinating conjunction | and, but, or |
| IN | Preposition / subordinating conjunction | in, on, because |

## Other

| Tag | Meaning | Example |
|-----|---------|---------|
| RP | Particle | up, off, out |
| EX | Existential "there" | there (as in there is) |
| FW | Foreign word | café, naïve |
| POS | Possessive ending | 's |
| TO | "to" | to (infinitive marker) |
| UH | Interjection | oh, wow, uh |
| SYM | Symbol | %, $, & |
| LS | List item marker | 1., A., a) |
| CD | Cardinal number | one, 2, 100 |

## Punctuation

| Tag | Meaning |
|-----|---------|
| . | Sentence-ending punctuation (. ! ?) |
| , | Comma |
| : | Colon or semicolon |
| `` | Opening quotation mark |
| '' | Closing quotation mark |
| -LRB- | Left bracket ( [ |
| -RRB- | Right bracket ) ] |

# %% [markdown]
# # Universal POS Tags (Simpler, Language-Agnostic)
#
# | Tag | Meaning |
# |-----|---------|
# | NOUN | Nouns |
# | VERB | Verbs |
# | ADJ | Adjectives |
# | ADV | Adverbs |
# | PRON | Pronouns |
# | DET | Determiners |
# | ADP | Adpositions (prepositions/postpositions) |
# | CONJ | Conjunctions |
# | NUM | Numerals |
# | PART | Particles |
# | INTJ | Interjections |
# | PUNCT | Punctuation |
# | SYM | Symbols |
# | X | Other/unknown |
